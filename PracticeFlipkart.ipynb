# %%
from bs4 import BeautifulSoup as bs
import requests as rq
import pandas as pd

# %%
link = "https://www.flipkart.com/realme-buds-2-wired-headset/product-reviews/itmaefc42e261f9d?pid=ACCFMGJYG25NE3BZ&lid=LSTACCFMGJYG25NE3BZVKPSTS&marketplace=FLIPKART"
page = rq.get(link)

# %%
page
# Out:
# <Response [200]>

# %%
soup = bs(page.content,'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.cdccfa.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#   <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# ...

# %%
name = soup.find_all('p',class_="_2sc7ZR _2V5EHH")
name
# Out:
# [<p class="_2sc7ZR _2V5EHH">Flipkart Customer</p>,
#  <p class="_2sc7ZR _2V5EHH">Kanhaiya khichi  khatik </p>,
#  <p class="_2sc7ZR _2V5EHH">Shivani Kadam</p>,
#  <p class="_2sc7ZR _2V5EHH">Chandu V</p>,
#  <p class="_2sc7ZR _2V5EHH">Arijit  Chatterjee </p>,
#  <p class="_2sc7ZR _2V5EHH">Suryabhan  Yadav</p>,
#  <p class="_2sc7ZR _2V5EHH">Sourav Roy</p>,
#  <p class="_2sc7ZR _2V5EHH">Rehan Khan</p>,
#  <p class="_2sc7ZR _2V5EHH">Aakash Bej</p>,
#  <p class="_2sc7ZR _2V5EHH">Aryan  Singh tiwari</p>]

# %%
cust_name=[]
for i in range(0,len(name)):
    cust_name.append(name[i].get_text())
cust_name
# Out:
# ['Flipkart Customer',
#  'Kanhaiya khichi  khatik ',
#  'Shivani Kadam',
#  'Chandu V',
#  'Arijit  Chatterjee ',
#  'Suryabhan  Yadav',
#  'Sourav Roy',
#  'Rehan Khan',
#  'Aakash Bej',
#  'Aryan  Singh tiwari']

# %%
c="https://www.flipkart.com/realme-buds-2-wired-headset/product-reviews/itmaefc42e261f9d?pid=ACCFMGJYG25NE3BZ&lid=LSTACCFMGJYG25NE3BZVKPSTS&marketplace=FLIPKART&page=2"
print(link==c)
# Out:
# False
